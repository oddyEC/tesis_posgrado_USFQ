# %% [markdown]
# ## Notebook 1: Extracción de Datos
# ### Descripción General
# Este notebook tiene como objetivo extraer los datos del dataset Bugs.jar. Para ello, accedemos a los repositorios Git, identificamos las ramas que contienen bugs, y extraemos los reportes y parches de cada bug.

# %% [markdown]
# ### Sección 1: Importación de Librerías

# %%
import os
import git
import yaml
from unidiff import PatchSet
import pandas as pd

# %% [markdown]
# ### Sección 2: Definición de Funciones

# %% [markdown]
# Función: process_project

# %%
# Esta función procesa un proyecto específico del dataset Bugs.jar.
# - Identifica todas las ramas que contienen bugs utilizando el prefijo 'bugs-dot-jar_'.
# - Hace checkout en cada rama para acceder a los archivos relevantes.
# - Lee el reporte del bug y el parche (diff) asociado.
# - Si los datos necesarios están presentes, almacena la información en una lista de diccionarios.

def process_project(project_path):
    repo = git.Repo(project_path)
    bug_branches = [ref.name for ref in repo.remote().refs if ref.name.startswith('origin/bugs-dot-jar_')]
    data = []

    for branch_name in bug_branches:
        print(f'Processing branch: {branch_name}')
        local_branch = branch_name.replace('origin/', '')
        try:
            # Crear o actualizar la rama local
            repo.git.checkout('-B', local_branch, branch_name)
        except Exception as e:
            print(f'Error checking out branch {branch_name}: {e}')
            continue

        # Después de hacer checkout, el directorio .bugs-dot-jar debería estar en project_path
        bug_dir = os.path.join(project_path, '.bugs-dot-jar')

        # Leer archivos necesarios
        bug_report = read_bug_report(bug_dir)
        patch_set = read_patch_set(bug_dir)

        if bug_report and patch_set:
            # Procesar los datos y añadir a la lista 'data'
            # (Tu código existente para procesar y extraer la información)
            data.append({
                'project': os.path.basename(project_path),
                'branch': local_branch,
                'bug_report': bug_report,
                # Agrega otros campos necesarios
            })
        else:
            print(f'Skipping branch {branch_name} due to missing data.')

    return data
# 1. Se accede al repositorio del proyecto mediante Git.
# 2. Se filtran las ramas que comienzan con 'origin/bugs-dot-jar_'.
# 3. Por cada rama:
#    - Se intenta hacer checkout en la rama correspondiente.
#    - Se accede al directorio '.bugs-dot-jar' que contiene los archivos necesarios.
# 4. Si se encuentran tanto el reporte del bug como el parche:
#    - Se almacena la información en un diccionario y se añade a la lista de resultados.

# %%
# Función: `read_bug_report`
# - Lee el archivo 'bug-report.yml' que contiene la información del bug.
# - Si el archivo no existe o está vacío, muestra un mensaje de advertencia.
# - Si el archivo se lee correctamente, se devuelve un diccionario con los datos del bug.

def read_bug_report(bug_dir):
    bug_report_path = os.path.join(bug_dir, 'bug-report.yml')
    if os.path.exists(bug_report_path):
        try:
            with open(bug_report_path, 'r', encoding='utf-8') as f:
                content = f.read()
                if not content.strip():
                    print(f'Bug report file is empty: {bug_report_path}')
                    return None
                return yaml.safe_load(content)
        except Exception as e:
            print(f'Error reading bug report {bug_report_path}: {e}')
            return None
    else:
        print(f'Bug report file does not exist: {bug_report_path}')
        return None
# 1. Si el archivo 'bug-report.yml' no existe:
#    - Se imprime un mensaje de advertencia.
# 2. Si el archivo está vacío:
#    - Se ignora el archivo y se devuelve None.
# 3. Si hay un error al leer el archivo:
#    - Se imprime el error y se devuelve None.

def read_patch_set(bug_dir):
    patch_path = os.path.join(bug_dir, 'developer-patch.diff')  # Ajuste del nombre del archivo
    if os.path.exists(patch_path):
        try:
            with open(patch_path, 'r', encoding='utf-8') as f:
                content = f.read()
                if not content.strip():
                    print(f'Patch file is empty: {patch_path}')
                    return None
                return PatchSet(content)
        except Exception as e:
            print(f'Error reading patch file {patch_path}: {e}')
            return None
    else:
        print(f'Patch file does not exist: {patch_path}')
        return None
# Función: `read_patch_set`
# - Lee el archivo 'developer-patch.diff' que contiene el parche asociado al bug.
# - Si el archivo no existe o está vacío, muestra un mensaje de advertencia.
# - Si se lee correctamente, se devuelve un PatchSet que representa los cambios.

# %%
def main():
    base_path = 'bugs-jar' 
    projects = ['accumulo', 'camel', 'commons-math', 'flink', 'jackrabbit-oak', 'logging-log4j2', 'maven', 'wicket']
    all_data = []

    for project_name in projects:
        project_path = os.path.join(base_path, project_name)
        print(f'Processing project: {project_name}')
        project_data = process_project(project_path)
        all_data.extend(project_data)

    # Convertir a DataFrame y guardar
    df = pd.DataFrame(all_data)
    df.to_csv('bugs_data1.csv', index=False)
    print('Data extraction complete. Saved to bugs_data1.csv.')

if __name__ == '__main__':
    main()
# Out:
# Processing project: accumulo
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1044_9396979b
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1044_ea2f9856
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1051_25cf3ccd
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1120_474b2577
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1183_742960f1
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1183_cfbf5999
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1190_e29dc4f5
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1192_9476b877
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1192_c489d866
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1199_813109d7
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1312_d9ab8449
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1348_6ff92b12
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1348_ef0f6ddc
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1358_4d10c92f
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1358_6c565dfb
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1505_994df698
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1505_b082fc1e
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1514_fb25913c
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1518_dc95cb69
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1518_df4b1985
# Processing branch: origin/bugs-dot-jar_ACCUMULO-151_b007b22e
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1544_0cf2ff72
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1661_13eb19c2
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1730_872b6db3
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1732_941e3cb1
# Processing branch: origin/bugs-dot-jar_ACCUMULO-178_2f0643a9
# Processing branch: origin/bugs-dot-jar_ACCUMULO-178_efef09b0
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1800_3143b9c5
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1800_8ec4cb84
# Processing branch: origin/bugs-dot-jar_ACCUMULO-189_6dbbdc21
# Processing branch: origin/bugs-dot-jar_ACCUMULO-189_cd7feb4d
# Processing branch: origin/bugs-dot-jar_ACCUMULO-193_8ad5a888
# Processing branch: origin/bugs-dot-jar_ACCUMULO-193_c831e44d
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1986_2d97b875
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1986_a5e3ed3b
# Processing branch: origin/bugs-dot-jar_ACCUMULO-1986_adee0f12
# Processing branch: origin/bugs-dot-jar_ACCUMULO-209_397f86f6
# Processing branch: origin/bugs-dot-jar_ACCUMULO-209_76d727f0
# Processing branch: origin/bugs-dot-jar_ACCUMULO-217_46f62443
# Processing branch: origin/bugs-dot-jar_ACCUMULO-217_add180fb
# Processing branch: origin/bugs-dot-jar_ACCUMULO-218_15476a0d
# Processing branch: origin/bugs-dot-jar_ACCUMULO-218_3d55560a
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2390_28294266
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2487_f2920c26
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2494_0dc92ca1
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2520_a64151e6
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2544_7ec60f1b
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2659_019edb16
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2671_17344890
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2713_6138a80f
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2742_1f7dd2d5
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2748_ff8c2383
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2857_9fcca2ed
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2899_31aea2ad
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2928_f99b5654
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2952_11d11e0d
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2962_023be574
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2962_2fd7633f
# Processing branch: origin/bugs-dot-jar_ACCUMULO-2974_5eceb10e
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3006_d6472040
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3015_f848178e
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3055_94c2a31f
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3077_17654199
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3143_ddd2c3bc
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3150_72fd6bec
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3218_1b35d263
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3229_891584fb
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3242_15e83709
# Processing branch: origin/bugs-dot-jar_ACCUMULO-334_9d8cc45d
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3383_97f16db4
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3385_a3267d3e
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3408_81d25bc2
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3424_27d4ee21
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3474_cfb832a1
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3475_7651b777
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3634_9339ecf8
# Processing branch: origin/bugs-dot-jar_ACCUMULO-366_db4a291f
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3718_73ce9cfb
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3746_47c64d9a
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3897_699b8bf0
# Processing branch: origin/bugs-dot-jar_ACCUMULO-3945_36225565
# Processing branch: origin/bugs-dot-jar_ACCUMULO-4029_5ca779a0
# Processing branch: origin/bugs-dot-jar_ACCUMULO-4098_a2c2d38a
# Processing branch: origin/bugs-dot-jar_ACCUMULO-4113_27300d81
# Processing branch: origin/bugs-dot-jar_ACCUMULO-412_5594b2e0
# Processing branch: origin/bugs-dot-jar_ACCUMULO-412_be2fdba7
# Processing branch: origin/bugs-dot-jar_ACCUMULO-4138_4d23d784
# Processing branch: origin/bugs-dot-jar_ACCUMULO-4138_50db442b
# Processing branch: origin/bugs-dot-jar_ACCUMULO-4138_eb0f9b41
# Processing branch: origin/bugs-dot-jar_ACCUMULO-414_116d5928
# Processing branch: origin/bugs-dot-jar_ACCUMULO-414_ebf22df0
# Processing branch: origin/bugs-dot-jar_ACCUMULO-633_8dad5e0f
# Processing branch: origin/bugs-dot-jar_ACCUMULO-776_dc9f23d9
# Processing branch: origin/bugs-dot-jar_ACCUMULO-795_9453bcfa
# Processing branch: origin/bugs-dot-jar_ACCUMULO-821_a450ac2f
# Processing branch: origin/bugs-dot-jar_ACCUMULO-843_65390f8c
# Processing branch: origin/bugs-dot-jar_ACCUMULO-844_692efde2
# Processing branch: origin/bugs-dot-jar_ACCUMULO-907_4aeaeb2a
# Processing project: camel
# Processing branch: origin/bugs-dot-jar_CAMEL-3276_205420e2
# Processing branch: origin/bugs-dot-jar_CAMEL-3281_f7dd2fff
# Processing branch: origin/bugs-dot-jar_CAMEL-3314_4badd9c5
# Processing branch: origin/bugs-dot-jar_CAMEL-3388_0919a0f6
# Processing branch: origin/bugs-dot-jar_CAMEL-3394_18e1a142
# Processing branch: origin/bugs-dot-jar_CAMEL-3395_8433e6db
# Processing branch: origin/bugs-dot-jar_CAMEL-3428_320545cd
# Processing branch: origin/bugs-dot-jar_CAMEL-3433_e76d23b0
# Processing branch: origin/bugs-dot-jar_CAMEL-3448_b345dd82
# Processing branch: origin/bugs-dot-jar_CAMEL-3498_b4606700
# Processing branch: origin/bugs-dot-jar_CAMEL-3531_41e4b5b9
# Processing branch: origin/bugs-dot-jar_CAMEL-3535_b56d2962
# Processing branch: origin/bugs-dot-jar_CAMEL-3545_050c542e
# Processing branch: origin/bugs-dot-jar_CAMEL-3617_02626724
# Processing branch: origin/bugs-dot-jar_CAMEL-3690_2a3f3392
# Processing branch: origin/bugs-dot-jar_CAMEL-3709_4c37e773
# Processing branch: origin/bugs-dot-jar_CAMEL-3727_ff2713d1
# Processing branch: origin/bugs-dot-jar_CAMEL-3757_c1b2f2f8
# Processing branch: origin/bugs-dot-jar_CAMEL-3760_5225e6e3
# Processing branch: origin/bugs-dot-jar_CAMEL-3789_9319e139
# Processing branch: origin/bugs-dot-jar_CAMEL-3791_52106681
# Processing branch: origin/bugs-dot-jar_CAMEL-3847_de9399f3
# Processing branch: origin/bugs-dot-jar_CAMEL-3878_b9094cb5
# Processing branch: origin/bugs-dot-jar_CAMEL-4011_cbffff59
# Processing branch: origin/bugs-dot-jar_CAMEL-4211_4efddb3f
# Processing branch: origin/bugs-dot-jar_CAMEL-4354_96e40c3c
# Processing branch: origin/bugs-dot-jar_CAMEL-4370_7345fefc
# Processing branch: origin/bugs-dot-jar_CAMEL-4388_f39bc60d
# Processing branch: origin/bugs-dot-jar_CAMEL-4467_79168a23
# Processing branch: origin/bugs-dot-jar_CAMEL-4474_06a8489a
# Processing branch: origin/bugs-dot-jar_CAMEL-4482_e38494f1
# Processing branch: origin/bugs-dot-jar_CAMEL-4486_f98ac676
# Processing branch: origin/bugs-dot-jar_CAMEL-4509_8e3450f4
# Processing branch: origin/bugs-dot-jar_CAMEL-4513_9e05f77f
# Processing branch: origin/bugs-dot-jar_CAMEL-4536_df9f4a6a
# Processing branch: origin/bugs-dot-jar_CAMEL-4542_c408c3ed
# Processing branch: origin/bugs-dot-jar_CAMEL-4682_1e54865c
# Processing branch: origin/bugs-dot-jar_CAMEL-5137_afa1d132
# Processing branch: origin/bugs-dot-jar_CAMEL-5140_8898d491
# Processing branch: origin/bugs-dot-jar_CAMEL-5154_a8586a69
# Processing branch: origin/bugs-dot-jar_CAMEL-5187_8cadc344
# Processing branch: origin/bugs-dot-jar_CAMEL-5215_033eb6fe
# Processing branch: origin/bugs-dot-jar_CAMEL-5224_2db5570f
# Processing branch: origin/bugs-dot-jar_CAMEL-5261_55c2e2d8
# Processing branch: origin/bugs-dot-jar_CAMEL-5357_4cf7e80e
# Processing branch: origin/bugs-dot-jar_CAMEL-5432_93935780
# Processing branch: origin/bugs-dot-jar_CAMEL-5437_da05f5aa
# Processing branch: origin/bugs-dot-jar_CAMEL-5515_b3bb8670
# Processing branch: origin/bugs-dot-jar_CAMEL-5570_a57830ed
# Processing branch: origin/bugs-dot-jar_CAMEL-5571_0e87b84f
# Processing branch: origin/bugs-dot-jar_CAMEL-5644_15d0fd9b
# Processing branch: origin/bugs-dot-jar_CAMEL-5681_78c73502
# Processing branch: origin/bugs-dot-jar_CAMEL-5683_0c3c7d1b
# Processing branch: origin/bugs-dot-jar_CAMEL-5699_6d63a502
# Processing branch: origin/bugs-dot-jar_CAMEL-5704_708e756d
# Processing branch: origin/bugs-dot-jar_CAMEL-5707_3f70d612
# Processing branch: origin/bugs-dot-jar_CAMEL-5720_4a05eccf
# Processing branch: origin/bugs-dot-jar_CAMEL-5796_de6dd425
# Processing branch: origin/bugs-dot-jar_CAMEL-5826_a04674f2
# Processing branch: origin/bugs-dot-jar_CAMEL-5844_e775071b
# Processing branch: origin/bugs-dot-jar_CAMEL-6447_020c451a
# Processing branch: origin/bugs-dot-jar_CAMEL-6557_2c5a42db
# Processing branch: origin/bugs-dot-jar_CAMEL-6593_7f8a295a
# Processing branch: origin/bugs-dot-jar_CAMEL-6604_4209fabb
# Processing branch: origin/bugs-dot-jar_CAMEL-6604_55751402
# Processing branch: origin/bugs-dot-jar_CAMEL-6607_2d7051ed
# Processing branch: origin/bugs-dot-jar_CAMEL-6610_ed7e7c9f
# Processing branch: origin/bugs-dot-jar_CAMEL-6667_1fc7bd7a
# Processing branch: origin/bugs-dot-jar_CAMEL-6687_617eab1c
# Processing branch: origin/bugs-dot-jar_CAMEL-6723_b92d6237
# Processing branch: origin/bugs-dot-jar_CAMEL-6743_745a85ab
# Processing branch: origin/bugs-dot-jar_CAMEL-6779_f412d744
# Processing branch: origin/bugs-dot-jar_CAMEL-6810_6b210169
# Processing branch: origin/bugs-dot-jar_CAMEL-6889_cd40b712
# Processing branch: origin/bugs-dot-jar_CAMEL-6918_5761250c
# Processing branch: origin/bugs-dot-jar_CAMEL-6936_4954d573
# Processing branch: origin/bugs-dot-jar_CAMEL-6948_f744afd9
# Processing branch: origin/bugs-dot-jar_CAMEL-6964_6b2ffb30
# Processing branch: origin/bugs-dot-jar_CAMEL-6987_37e0e6bb
# Processing branch: origin/bugs-dot-jar_CAMEL-7016_4ed448c7
# Processing branch: origin/bugs-dot-jar_CAMEL-7018_3244c1e5
# Processing branch: origin/bugs-dot-jar_CAMEL-7055_15e1077d
# Processing branch: origin/bugs-dot-jar_CAMEL-7100_00a9b02b
# Processing branch: origin/bugs-dot-jar_CAMEL-7125_6641f182
# Processing branch: origin/bugs-dot-jar_CAMEL-7130_7c9326f4
# Processing branch: origin/bugs-dot-jar_CAMEL-7130_cc192f87
# Processing branch: origin/bugs-dot-jar_CAMEL-7146_b6981cfd
# Processing branch: origin/bugs-dot-jar_CAMEL-7160_095fa2b4
# Processing branch: origin/bugs-dot-jar_CAMEL-7163_5f726d0b
# Processing branch: origin/bugs-dot-jar_CAMEL-7167_1e33fcbc
# Processing branch: origin/bugs-dot-jar_CAMEL-7209_5f78c646
# Processing branch: origin/bugs-dot-jar_CAMEL-7213_336663c9
# Processing branch: origin/bugs-dot-jar_CAMEL-7239_ae419224
# Processing branch: origin/bugs-dot-jar_CAMEL-7241_18c23fa8
# Processing branch: origin/bugs-dot-jar_CAMEL-7271_a5a2f750
# Processing branch: origin/bugs-dot-jar_CAMEL-7275_44cad623
# Processing branch: origin/bugs-dot-jar_CAMEL-7304_fa165d6b
# Processing branch: origin/bugs-dot-jar_CAMEL-7344_91228815
# Processing branch: origin/bugs-dot-jar_CAMEL-7359_9cb09d14
# Processing branch: origin/bugs-dot-jar_CAMEL-7359_e6fbbf04
# Processing branch: origin/bugs-dot-jar_CAMEL-7364_7bbb88ba
# Processing branch: origin/bugs-dot-jar_CAMEL-7418_cabee0e9
# Processing branch: origin/bugs-dot-jar_CAMEL-7429_43956f93
# Processing branch: origin/bugs-dot-jar_CAMEL-7448_35bde2b2
# Processing branch: origin/bugs-dot-jar_CAMEL-7456_02da984a
# Processing branch: origin/bugs-dot-jar_CAMEL-7459_57ba1bde
# Processing branch: origin/bugs-dot-jar_CAMEL-7478_69b00a31
# Processing branch: origin/bugs-dot-jar_CAMEL-7513_85ced066
# Processing branch: origin/bugs-dot-jar_CAMEL-7562_689147e9
# Processing branch: origin/bugs-dot-jar_CAMEL-7568_b3377b16
# Processing branch: origin/bugs-dot-jar_CAMEL-7586_1f92fa42
# Processing branch: origin/bugs-dot-jar_CAMEL-7611_e30f1c53
# Processing branch: origin/bugs-dot-jar_CAMEL-7622_faa20255
# Processing branch: origin/bugs-dot-jar_CAMEL-7736_7ad36e3d
# Processing branch: origin/bugs-dot-jar_CAMEL-7767_eab06182
# Processing branch: origin/bugs-dot-jar_CAMEL-7795_19b2aa31
# Processing branch: origin/bugs-dot-jar_CAMEL-7883_d57f402b
# Processing branch: origin/bugs-dot-jar_CAMEL-7973_799b45df
# Processing branch: origin/bugs-dot-jar_CAMEL-7990_d581c4a4
# Processing branch: origin/bugs-dot-jar_CAMEL-8053_cac72b14
# Processing branch: origin/bugs-dot-jar_CAMEL-8081_2e985f9b
# Processing branch: origin/bugs-dot-jar_CAMEL-8106_39ccf5d6
# Processing branch: origin/bugs-dot-jar_CAMEL-8125_36e7b668
# Processing branch: origin/bugs-dot-jar_CAMEL-8137_53b4e90c
# Processing branch: origin/bugs-dot-jar_CAMEL-8146_17475d80
# Processing branch: origin/bugs-dot-jar_CAMEL-8227_54d7fc59
# Processing branch: origin/bugs-dot-jar_CAMEL-8584_dd0f74c0
# Processing branch: origin/bugs-dot-jar_CAMEL-8592_57f72cd9
# Processing branch: origin/bugs-dot-jar_CAMEL-8624_597883fa
# Processing branch: origin/bugs-dot-jar_CAMEL-8626_d063f471
# Processing branch: origin/bugs-dot-jar_CAMEL-8954_7b1253db
# Processing branch: origin/bugs-dot-jar_CAMEL-8964_ea8ee025
# Processing branch: origin/bugs-dot-jar_CAMEL-9032_108d94f7
# Processing branch: origin/bugs-dot-jar_CAMEL-9124_9da2c05a
# Processing branch: origin/bugs-dot-jar_CAMEL-9143_08077733
# Processing branch: origin/bugs-dot-jar_CAMEL-9217_e7ac45b6
# Processing branch: origin/bugs-dot-jar_CAMEL-9238_169b981e
# Processing branch: origin/bugs-dot-jar_CAMEL-9243_1957a828
# Processing branch: origin/bugs-dot-jar_CAMEL-9269_62b2042b
# Processing branch: origin/bugs-dot-jar_CAMEL-9340_1cab39f6
# Processing branch: origin/bugs-dot-jar_CAMEL-9444_baece126
# Processing branch: origin/bugs-dot-jar_CAMEL-9480_0ead2cac
# Processing branch: origin/bugs-dot-jar_CAMEL-9641_9a6e6d8a
# Processing branch: origin/bugs-dot-jar_CAMEL-9666_da035952
# Processing branch: origin/bugs-dot-jar_CAMEL-9672_84922699
# Processing branch: origin/bugs-dot-jar_CAMEL-9673_7944093f
# Processing branch: origin/bugs-dot-jar_CAMEL-9700_4d03e9de
# Processing project: commons-math
# Processing branch: origin/bugs-dot-jar_MATH-1005_91d280b7
# Processing branch: origin/bugs-dot-jar_MATH-1045_a4ffd393
# Processing branch: origin/bugs-dot-jar_MATH-1045_c979a6f0
# Processing branch: origin/bugs-dot-jar_MATH-1051_bda25b40
# Processing branch: origin/bugs-dot-jar_MATH-1058_4ebd967c
# Processing branch: origin/bugs-dot-jar_MATH-1065_996c0c16
# Processing branch: origin/bugs-dot-jar_MATH-1067_aff82362
# Processing branch: origin/bugs-dot-jar_MATH-1068_b12610d3
# Processing branch: origin/bugs-dot-jar_MATH-1070_8e5867ed
# Processing branch: origin/bugs-dot-jar_MATH-1080_b285f170
# Processing branch: origin/bugs-dot-jar_MATH-1088_63d88c74
# Processing branch: origin/bugs-dot-jar_MATH-1089_e91d0f05
# Processing branch: origin/bugs-dot-jar_MATH-1093_7cfbc0da
# Processing branch: origin/bugs-dot-jar_MATH-1096_19c1c3bb
# Processing branch: origin/bugs-dot-jar_MATH-1096_faf99727
# Processing branch: origin/bugs-dot-jar_MATH-1103_a6f96306
# Processing branch: origin/bugs-dot-jar_MATH-1106_e2dc384d
# Processing branch: origin/bugs-dot-jar_MATH-1115_2a6c6409
# Processing branch: origin/bugs-dot-jar_MATH-1117_f4c926ea
# Processing branch: origin/bugs-dot-jar_MATH-1121_5a6ccd58
# Processing branch: origin/bugs-dot-jar_MATH-1123_a197ba85
# Processing branch: origin/bugs-dot-jar_MATH-1127_ba62c59d
# Processing branch: origin/bugs-dot-jar_MATH-1129_d4f978dd
# Processing branch: origin/bugs-dot-jar_MATH-1135_a7363a2a
# Processing branch: origin/bugs-dot-jar_MATH-1136_cc4ab51e
# Processing branch: origin/bugs-dot-jar_MATH-1141_2f2a2dda
# Processing branch: origin/bugs-dot-jar_MATH-1148_4080feff
# Processing branch: origin/bugs-dot-jar_MATH-1165_596ccd59
# Processing branch: origin/bugs-dot-jar_MATH-1203_4aa4c6d3
# Processing branch: origin/bugs-dot-jar_MATH-1203_b148046a
# Processing branch: origin/bugs-dot-jar_MATH-1204_a56d4998
# Processing branch: origin/bugs-dot-jar_MATH-1208_ce2badf0
# Processing branch: origin/bugs-dot-jar_MATH-1211_a06a1584
# Processing branch: origin/bugs-dot-jar_MATH-1226_c44bfe00
# Processing branch: origin/bugs-dot-jar_MATH-1230_96eb80ef
# Processing branch: origin/bugs-dot-jar_MATH-1232_8f35fcb8
# Processing branch: origin/bugs-dot-jar_MATH-1241_471e6b07
# Processing branch: origin/bugs-dot-jar_MATH-1252_09fe956a
# Processing branch: origin/bugs-dot-jar_MATH-1256_41f29780
# Processing branch: origin/bugs-dot-jar_MATH-1257_03178c8b
# Processing branch: origin/bugs-dot-jar_MATH-1261_4c4b3e2e
# Processing branch: origin/bugs-dot-jar_MATH-1269_a94ff90a
# Processing branch: origin/bugs-dot-jar_MATH-1272_26e878ab
# Processing branch: origin/bugs-dot-jar_MATH-1277_fb007815
# Processing branch: origin/bugs-dot-jar_MATH-1283_9e0c5ad4
# Processing branch: origin/bugs-dot-jar_MATH-1297_56434517
# Processing branch: origin/bugs-dot-jar_MATH-1300_1d635088
# Processing branch: origin/bugs-dot-jar_MATH-286_dbdff075
# Processing branch: origin/bugs-dot-jar_MATH-288_38983e82
# Processing branch: origin/bugs-dot-jar_MATH-290_b01fcc31
# Processing branch: origin/bugs-dot-jar_MATH-293_59a0da9c
# Processing branch: origin/bugs-dot-jar_MATH-294_2c8a114f
# Processing branch: origin/bugs-dot-jar_MATH-305_ef9b639a
# Processing branch: origin/bugs-dot-jar_MATH-309_0596e314
# Processing branch: origin/bugs-dot-jar_MATH-318_83f18d52
# Processing branch: origin/bugs-dot-jar_MATH-320_b2f3f6db
# Processing branch: origin/bugs-dot-jar_MATH-320_c06cc933
# Processing branch: origin/bugs-dot-jar_MATH-326_ce185345
# Processing branch: origin/bugs-dot-jar_MATH-327_262fe4c0
# Processing branch: origin/bugs-dot-jar_MATH-329_6dd3724b
# Processing branch: origin/bugs-dot-jar_MATH-338_8dd22390
# Processing branch: origin/bugs-dot-jar_MATH-343_f6dd42b4
# Processing branch: origin/bugs-dot-jar_MATH-344_a0b4b4b7
# Processing branch: origin/bugs-dot-jar_MATH-349_4cc9a49d
# Processing branch: origin/bugs-dot-jar_MATH-358_061f5017
# Processing branch: origin/bugs-dot-jar_MATH-367_3a15d8ce
# Processing branch: origin/bugs-dot-jar_MATH-369_f4a4464b
# Processing branch: origin/bugs-dot-jar_MATH-370_495f04bc
# Processing branch: origin/bugs-dot-jar_MATH-371_bb005b56
# Processing branch: origin/bugs-dot-jar_MATH-373_bfe4623c
# Processing branch: origin/bugs-dot-jar_MATH-377_c640932d
# Processing branch: origin/bugs-dot-jar_MATH-393_d4b02f6a
# Processing branch: origin/bugs-dot-jar_MATH-395_962315ba
# Processing branch: origin/bugs-dot-jar_MATH-405_784e4f69
# Processing branch: origin/bugs-dot-jar_MATH-413_51aa6e6c
# Processing branch: origin/bugs-dot-jar_MATH-414_5fe9b36c
# Processing branch: origin/bugs-dot-jar_MATH-434_133cbc2d
# Processing branch: origin/bugs-dot-jar_MATH-471_a4b1948b
# Processing branch: origin/bugs-dot-jar_MATH-482_6d6649ef
# Processing branch: origin/bugs-dot-jar_MATH-519_26a61077
# Processing branch: origin/bugs-dot-jar_MATH-546_b6bf8f41
# Processing branch: origin/bugs-dot-jar_MATH-554_fbbb96eb
# Processing branch: origin/bugs-dot-jar_MATH-555_328513f3
# Processing branch: origin/bugs-dot-jar_MATH-559_fc409e88
# Processing branch: origin/bugs-dot-jar_MATH-618_2123f780
# Processing branch: origin/bugs-dot-jar_MATH-631_334c01e6
# Processing branch: origin/bugs-dot-jar_MATH-631_c0b49542
# Processing branch: origin/bugs-dot-jar_MATH-631_ebc61de9
# Processing branch: origin/bugs-dot-jar_MATH-639_8b418000
# Processing branch: origin/bugs-dot-jar_MATH-640_98556fed
# Processing branch: origin/bugs-dot-jar_MATH-657_32b0f733
# Processing branch: origin/bugs-dot-jar_MATH-657_97b440fc
# Processing branch: origin/bugs-dot-jar_MATH-679_5e638976
# Processing branch: origin/bugs-dot-jar_MATH-691_118f0cc0
# Processing branch: origin/bugs-dot-jar_MATH-695_7980a242
# Processing branch: origin/bugs-dot-jar_MATH-699_b2e24119
# Processing branch: origin/bugs-dot-jar_MATH-704_3f645310
# Processing branch: origin/bugs-dot-jar_MATH-705_645d642b
# Processing branch: origin/bugs-dot-jar_MATH-713_f656676e
# Processing branch: origin/bugs-dot-jar_MATH-716_faa77857
# Processing branch: origin/bugs-dot-jar_MATH-718_3a08bfa6
# Processing branch: origin/bugs-dot-jar_MATH-722_95d15eff
# Processing branch: origin/bugs-dot-jar_MATH-723_1352a70f
# Processing branch: origin/bugs-dot-jar_MATH-724_9c8bb934
# Processing branch: origin/bugs-dot-jar_MATH-727_69273dca
# Processing branch: origin/bugs-dot-jar_MATH-727_d2777388
# Processing branch: origin/bugs-dot-jar_MATH-738_f64b6a90
# Processing branch: origin/bugs-dot-jar_MATH-744_8a83581e
# Processing branch: origin/bugs-dot-jar_MATH-757_76b7413d
# Processing branch: origin/bugs-dot-jar_MATH-776_b9ca51f0
# Processing branch: origin/bugs-dot-jar_MATH-778_5b9302d5
# Processing branch: origin/bugs-dot-jar_MATH-779_ebadb558
# Processing branch: origin/bugs-dot-jar_MATH-780_dd6cefb0
# Processing branch: origin/bugs-dot-jar_MATH-781_3c4cb189
# Processing branch: origin/bugs-dot-jar_MATH-789_621bbb8f
# Processing branch: origin/bugs-dot-jar_MATH-801_118e94b5
# Processing branch: origin/bugs-dot-jar_MATH-812_607c9ec6
# Processing branch: origin/bugs-dot-jar_MATH-812_6eb46555
# Processing branch: origin/bugs-dot-jar_MATH-828_a49e443c
# Processing branch: origin/bugs-dot-jar_MATH-835_63a48705
# Processing branch: origin/bugs-dot-jar_MATH-836_d7c0f27e
# Processing branch: origin/bugs-dot-jar_MATH-844_7994d3ee
# Processing branch: origin/bugs-dot-jar_MATH-848_ad252a8c
# Processing branch: origin/bugs-dot-jar_MATH-855_350f726c
# Processing branch: origin/bugs-dot-jar_MATH-855_ac597cc1
# Processing branch: origin/bugs-dot-jar_MATH-859_66dece12
# Processing branch: origin/bugs-dot-jar_MATH-864_abe53a53
# Processing branch: origin/bugs-dot-jar_MATH-865_b55e0206
# Processing branch: origin/bugs-dot-jar_MATH-867_bfbb156d
# Processing branch: origin/bugs-dot-jar_MATH-880_2a9cbbab
# Processing branch: origin/bugs-dot-jar_MATH-891_2b852d79
# Processing branch: origin/bugs-dot-jar_MATH-899_ce126bdb
# Processing branch: origin/bugs-dot-jar_MATH-904_6844aba9
# Processing branch: origin/bugs-dot-jar_MATH-924_2836a6f9
# Processing branch: origin/bugs-dot-jar_MATH-924_b07ecae3
# Processing branch: origin/bugs-dot-jar_MATH-927_185e3033
# Processing branch: origin/bugs-dot-jar_MATH-929_cedf0d27
# Processing branch: origin/bugs-dot-jar_MATH-934_724795b5
# Processing branch: origin/bugs-dot-jar_MATH-935_48dde378
# Processing branch: origin/bugs-dot-jar_MATH-938_73605560
# Processing branch: origin/bugs-dot-jar_MATH-939_49444ee6
# Processing branch: origin/bugs-dot-jar_MATH-942_0d057fc6
# Processing branch: origin/bugs-dot-jar_MATH-949_f83bbc1d
# Processing branch: origin/bugs-dot-jar_MATH-950_424cbd20
# Processing branch: origin/bugs-dot-jar_MATH-957_9aabf587
# Processing branch: origin/bugs-dot-jar_MATH-988_d270055e
# Processing branch: origin/bugs-dot-jar_MATH-996_86545dab
# Processing project: flink
# Processing branch: origin/bugs-dot-jar_FLINK-1133_02c08456
# Processing branch: origin/bugs-dot-jar_FLINK-1133_27e40205
# Processing branch: origin/bugs-dot-jar_FLINK-1145_22c370d9
# Processing branch: origin/bugs-dot-jar_FLINK-1167_259f10c0
# Processing branch: origin/bugs-dot-jar_FLINK-1214_6ecd0f82
# Processing branch: origin/bugs-dot-jar_FLINK-1290_45fb6d82
# Processing branch: origin/bugs-dot-jar_FLINK-1311_94c8e3fa
# Processing branch: origin/bugs-dot-jar_FLINK-1333_63ef8e86
# Processing branch: origin/bugs-dot-jar_FLINK-1382_9cd96df7
# Processing branch: origin/bugs-dot-jar_FLINK-1437_fb7ce0e3
# Processing branch: origin/bugs-dot-jar_FLINK-1458_91f9bfc7
# Processing branch: origin/bugs-dot-jar_FLINK-1471_d033fa8f
# Processing branch: origin/bugs-dot-jar_FLINK-1496_0a4c7694
# Processing branch: origin/bugs-dot-jar_FLINK-1531_21f47d9c
# Processing branch: origin/bugs-dot-jar_FLINK-1640_8f321c72
# Processing branch: origin/bugs-dot-jar_FLINK-1686_1f726e48
# Processing branch: origin/bugs-dot-jar_FLINK-1705_5308ac83
# Processing branch: origin/bugs-dot-jar_FLINK-1761_380ef878
# Processing branch: origin/bugs-dot-jar_FLINK-1820_39d526e6
# Processing branch: origin/bugs-dot-jar_FLINK-1848_7164b2b6
# Processing branch: origin/bugs-dot-jar_FLINK-1922_ccd574a4
# Processing branch: origin/bugs-dot-jar_FLINK-1930_4dbf030a
# Processing branch: origin/bugs-dot-jar_FLINK-1951_adb321d6
# Processing branch: origin/bugs-dot-jar_FLINK-1978_0078c44e
# Processing branch: origin/bugs-dot-jar_FLINK-1985_495a5c3c
# Processing branch: origin/bugs-dot-jar_FLINK-2074_6bc6dbec
# Processing branch: origin/bugs-dot-jar_FLINK-2082_0cfa43d7
# Processing branch: origin/bugs-dot-jar_FLINK-2109_d594d024
# Processing branch: origin/bugs-dot-jar_FLINK-2121_03340919
# Processing branch: origin/bugs-dot-jar_FLINK-2294_fef9f115
# Processing branch: origin/bugs-dot-jar_FLINK-2412_a56aad74
# Processing branch: origin/bugs-dot-jar_FLINK-2437_a41bc8cc
# Processing branch: origin/bugs-dot-jar_FLINK-2442_30761572
# Processing branch: origin/bugs-dot-jar_FLINK-2447_5546a1ef
# Processing branch: origin/bugs-dot-jar_FLINK-2460_a17d4e82
# Processing branch: origin/bugs-dot-jar_FLINK-2484_d738430c
# Processing branch: origin/bugs-dot-jar_FLINK-2515_06e2da35
# Processing branch: origin/bugs-dot-jar_FLINK-2567_948b6e05
# Processing branch: origin/bugs-dot-jar_FLINK-2658_ce68cbd9
# Processing branch: origin/bugs-dot-jar_FLINK-2707_3e233a38
# Processing branch: origin/bugs-dot-jar_FLINK-2713_63d9800e
# Processing branch: origin/bugs-dot-jar_FLINK-2734_8b40bb7a
# Processing branch: origin/bugs-dot-jar_FLINK-2754_68912126
# Processing branch: origin/bugs-dot-jar_FLINK-2763_af477563
# Processing branch: origin/bugs-dot-jar_FLINK-2800_b654e989
# Processing branch: origin/bugs-dot-jar_FLINK-2802_88a97768
# Processing branch: origin/bugs-dot-jar_FLINK-2812_e494c279
# Processing branch: origin/bugs-dot-jar_FLINK-2817_5dfc897b
# Processing branch: origin/bugs-dot-jar_FLINK-2874_17e7b423
# Processing branch: origin/bugs-dot-jar_FLINK-2964_76bebd42
# Processing branch: origin/bugs-dot-jar_FLINK-2968_59685903
# Processing branch: origin/bugs-dot-jar_FLINK-3011_5a86a0a1
# Processing branch: origin/bugs-dot-jar_FLINK-3011_a402002d
# Processing branch: origin/bugs-dot-jar_FLINK-3052_8dc70f2e
# Processing branch: origin/bugs-dot-jar_FLINK-3107_937963e3
# Processing branch: origin/bugs-dot-jar_FLINK-3189_a5b05566
# Processing branch: origin/bugs-dot-jar_FLINK-3251_117ba95f
# Processing branch: origin/bugs-dot-jar_FLINK-3256_44061882
# Processing branch: origin/bugs-dot-jar_FLINK-3260_6968a57a
# Processing branch: origin/bugs-dot-jar_FLINK-3267_ed3810b1
# Processing branch: origin/bugs-dot-jar_FLINK-3314_8fc7e7af
# Processing branch: origin/bugs-dot-jar_FLINK-3342_8e3e2f8f
# Processing branch: origin/bugs-dot-jar_FLINK-3513_d90672fd
# Processing branch: origin/bugs-dot-jar_FLINK-3534_734ba01d
# Processing branch: origin/bugs-dot-jar_FLINK-3566_434e88fd
# Processing branch: origin/bugs-dot-jar_FLINK-3684_e3759a5e
# Processing branch: origin/bugs-dot-jar_FLINK-3740_f2f5bd5b
# Processing branch: origin/bugs-dot-jar_FLINK-3760_494212b3
# Processing branch: origin/bugs-dot-jar_FLINK-3762_dc78a747
# Processing branch: origin/bugs-dot-jar_FLINK-996_32a003d5
# Processing project: jackrabbit-oak
# Processing branch: origin/bugs-dot-jar_OAK-1020_83427028
# Processing branch: origin/bugs-dot-jar_OAK-1024_2b5d3afb
# Processing branch: origin/bugs-dot-jar_OAK-1024_e39b4d96
# Processing branch: origin/bugs-dot-jar_OAK-1024_ecc5bdfd
# Processing branch: origin/bugs-dot-jar_OAK-1035_b2ca8baa
# Processing branch: origin/bugs-dot-jar_OAK-1054_0adf3a6e
# Processing branch: origin/bugs-dot-jar_OAK-1075_79467350
# Processing branch: origin/bugs-dot-jar_OAK-1076_9238264d
# Processing branch: origin/bugs-dot-jar_OAK-1081_4ce4e3c9
# Processing branch: origin/bugs-dot-jar_OAK-1093_531aca78
# Processing branch: origin/bugs-dot-jar_OAK-1093_d7f0f180
# Processing branch: origin/bugs-dot-jar_OAK-1094_2e20589f
# Processing branch: origin/bugs-dot-jar_OAK-1096_be44b816
# Processing branch: origin/bugs-dot-jar_OAK-1104_7ae92779
# Processing branch: origin/bugs-dot-jar_OAK-1108_a8c925e0
# Processing branch: origin/bugs-dot-jar_OAK-1111_459bd065
# Processing branch: origin/bugs-dot-jar_OAK-1122_5286861d
# Processing branch: origin/bugs-dot-jar_OAK-1129_2f95b81f
# Processing branch: origin/bugs-dot-jar_OAK-1155_f64e8adc
# Processing branch: origin/bugs-dot-jar_OAK-1168_c05cec12
# Processing branch: origin/bugs-dot-jar_OAK-1173_61c877d8
# Processing branch: origin/bugs-dot-jar_OAK-1174_342809f7
# Processing branch: origin/bugs-dot-jar_OAK-1178_84fb6b29
# Processing branch: origin/bugs-dot-jar_OAK-1178_f2bb1a17
# Processing branch: origin/bugs-dot-jar_OAK-1184_f72dd8d1
# Processing branch: origin/bugs-dot-jar_OAK-1186_52372042
# Processing branch: origin/bugs-dot-jar_OAK-1208_cb3ac20d
# Processing branch: origin/bugs-dot-jar_OAK-1215_a9efe3c4
# Processing branch: origin/bugs-dot-jar_OAK-1216_e403e003
# Processing branch: origin/bugs-dot-jar_OAK-1225_3535afe2
# Processing branch: origin/bugs-dot-jar_OAK-1227_117b0a3d
# Processing branch: origin/bugs-dot-jar_OAK-1235_1beb2a50
# Processing branch: origin/bugs-dot-jar_OAK-1244_b4a93c81
# Processing branch: origin/bugs-dot-jar_OAK-1250_0c3b3306
# Processing branch: origin/bugs-dot-jar_OAK-1254_25a70439
# Processing branch: origin/bugs-dot-jar_OAK-1269_b8fe2ded
# Processing branch: origin/bugs-dot-jar_OAK-1270_70564c7c
# Processing branch: origin/bugs-dot-jar_OAK-1287_14849e22
# Processing branch: origin/bugs-dot-jar_OAK-1289_0c3e3d70
# Processing branch: origin/bugs-dot-jar_OAK-1297_73cc2442
# Processing branch: origin/bugs-dot-jar_OAK-1308_69ba2a54
# Processing branch: origin/bugs-dot-jar_OAK-1320_64045631
# Processing branch: origin/bugs-dot-jar_OAK-1348_bc7b7e8c
# Processing branch: origin/bugs-dot-jar_OAK-135_438e31a7
# Processing branch: origin/bugs-dot-jar_OAK-1363_69b68890
# Processing branch: origin/bugs-dot-jar_OAK-1364_05c89637
# Processing branch: origin/bugs-dot-jar_OAK-1364_b481a14c
# Processing branch: origin/bugs-dot-jar_OAK-1369_ce0b0955
# Processing branch: origin/bugs-dot-jar_OAK-1429_279bb3ce
# Processing branch: origin/bugs-dot-jar_OAK-1429_c2f5ca6c
# Processing branch: origin/bugs-dot-jar_OAK-1432_808ac9c0
# Processing branch: origin/bugs-dot-jar_OAK-1460_f1ba7a42
# Processing branch: origin/bugs-dot-jar_OAK-1467_dde7de85
# Processing branch: origin/bugs-dot-jar_OAK-1516_7c62bd81
# Processing branch: origin/bugs-dot-jar_OAK-1614_86edbffb
# Processing branch: origin/bugs-dot-jar_OAK-1624_6d8146f8
# Processing branch: origin/bugs-dot-jar_OAK-1648_fdc54465
# Processing branch: origin/bugs-dot-jar_OAK-1655_01a8b283
# Processing branch: origin/bugs-dot-jar_OAK-1655_c91bfa54
# Processing branch: origin/bugs-dot-jar_OAK-1662_3efb5cbf
# Processing branch: origin/bugs-dot-jar_OAK-1668_63070cf9
# Processing branch: origin/bugs-dot-jar_OAK-1674_073b814c
# Processing branch: origin/bugs-dot-jar_OAK-1697_1552be04
# Processing branch: origin/bugs-dot-jar_OAK-1719_c3773d53
# Processing branch: origin/bugs-dot-jar_OAK-1727_26041fe7
# Processing branch: origin/bugs-dot-jar_OAK-1729_7ba9dd66
# Processing branch: origin/bugs-dot-jar_OAK-1731_024e5d37
# Processing branch: origin/bugs-dot-jar_OAK-1739_8188ef54
# Processing branch: origin/bugs-dot-jar_OAK-1749_591e4d4a
# Processing branch: origin/bugs-dot-jar_OAK-1761_f37ce716
# Processing branch: origin/bugs-dot-jar_OAK-1770_192ee9e4
# Processing branch: origin/bugs-dot-jar_OAK-1779_9d36bede
# Processing branch: origin/bugs-dot-jar_OAK-1784_2426deae
# Processing branch: origin/bugs-dot-jar_OAK-1788_dd3437d4
# Processing branch: origin/bugs-dot-jar_OAK-1789_07646fba
# Processing branch: origin/bugs-dot-jar_OAK-1789_08ba79d4
# Processing branch: origin/bugs-dot-jar_OAK-1789_9f7c1df0
# Processing branch: origin/bugs-dot-jar_OAK-1793_16225d51
# Processing branch: origin/bugs-dot-jar_OAK-1807_077efee5
# Processing branch: origin/bugs-dot-jar_OAK-1817_78c37386
# Processing branch: origin/bugs-dot-jar_OAK-1822_016df669
# Processing branch: origin/bugs-dot-jar_OAK-1822_3e83a4c1
# Processing branch: origin/bugs-dot-jar_OAK-1829_ca36450e
# Processing branch: origin/bugs-dot-jar_OAK-1848_093b9128
# Processing branch: origin/bugs-dot-jar_OAK-185_7fe28a0e
# Processing branch: origin/bugs-dot-jar_OAK-1874_3ae276c1
# Processing branch: origin/bugs-dot-jar_OAK-1877_716e1237
# Processing branch: origin/bugs-dot-jar_OAK-1883_9c2421ed
# Processing branch: origin/bugs-dot-jar_OAK-1894_35562cce
# Processing branch: origin/bugs-dot-jar_OAK-1899_b6f89048
# Processing branch: origin/bugs-dot-jar_OAK-1899_df59fb45
# Processing branch: origin/bugs-dot-jar_OAK-1916_705ce1d1
# Processing branch: origin/bugs-dot-jar_OAK-1926_9225a3e2
# Processing branch: origin/bugs-dot-jar_OAK-1932_913c2f53
# Processing branch: origin/bugs-dot-jar_OAK-1932_c215b267
# Processing branch: origin/bugs-dot-jar_OAK-1933_2e16a983
# Processing branch: origin/bugs-dot-jar_OAK-1959_93c1aa40
# Processing branch: origin/bugs-dot-jar_OAK-1977_4bfbfcdd
# Processing branch: origin/bugs-dot-jar_OAK-1985_f620b79b
# Processing branch: origin/bugs-dot-jar_OAK-2021_004db804
# Processing branch: origin/bugs-dot-jar_OAK-2029_e30023ba
# Processing branch: origin/bugs-dot-jar_OAK-2047_a0a495f0
# Processing branch: origin/bugs-dot-jar_OAK-2047_ca63fdf3
# Processing branch: origin/bugs-dot-jar_OAK-2049_4af0d4ee
# Processing branch: origin/bugs-dot-jar_OAK-2062_5c4589bd
# Processing branch: origin/bugs-dot-jar_OAK-208_daf9a4ef
# Processing branch: origin/bugs-dot-jar_OAK-2117_c7669f31
# Processing branch: origin/bugs-dot-jar_OAK-2147_a1556c30
# Processing branch: origin/bugs-dot-jar_OAK-2174_5931a4a7
# Processing branch: origin/bugs-dot-jar_OAK-2219_f2740ce1
# Processing branch: origin/bugs-dot-jar_OAK-2235_29d3d8f1
# Processing branch: origin/bugs-dot-jar_OAK-2238_a28098fd
# Processing branch: origin/bugs-dot-jar_OAK-2246_dcadb0e1
# Processing branch: origin/bugs-dot-jar_OAK-2249_6dde8e9d
# Processing branch: origin/bugs-dot-jar_OAK-2250_08b25cb0
# Processing branch: origin/bugs-dot-jar_OAK-225_e33328e0
# Processing branch: origin/bugs-dot-jar_OAK-2260_0ac7ff20
# Processing branch: origin/bugs-dot-jar_OAK-2288_57bd2dc5
# Processing branch: origin/bugs-dot-jar_OAK-2308_f4d5bbe1
# Processing branch: origin/bugs-dot-jar_OAK-2311_ca85ecce
# Processing branch: origin/bugs-dot-jar_OAK-2318_1d08cbd3
# Processing branch: origin/bugs-dot-jar_OAK-2330_408a566e
# Processing branch: origin/bugs-dot-jar_OAK-2336_d0f6715d
# Processing branch: origin/bugs-dot-jar_OAK-2345_a0dc4c89
# Processing branch: origin/bugs-dot-jar_OAK-2355_74f22886
# Processing branch: origin/bugs-dot-jar_OAK-2359_b3071839
# Processing branch: origin/bugs-dot-jar_OAK-2363_90ea7aa5
# Processing branch: origin/bugs-dot-jar_OAK-2388_487de751
# Processing branch: origin/bugs-dot-jar_OAK-2389_0fa892b3
# Processing branch: origin/bugs-dot-jar_OAK-2389_7c320b1e
# Processing branch: origin/bugs-dot-jar_OAK-2389_8079f7b5
# Processing branch: origin/bugs-dot-jar_OAK-238_24ce6788
# Processing branch: origin/bugs-dot-jar_OAK-2418_039f892d
# Processing branch: origin/bugs-dot-jar_OAK-2420_24cb1908
# Processing branch: origin/bugs-dot-jar_OAK-2426_920f32d0
# Processing branch: origin/bugs-dot-jar_OAK-2427_e6d4f9a6
# Processing branch: origin/bugs-dot-jar_OAK-2430_be3a9114
# Processing branch: origin/bugs-dot-jar_OAK-2433_7fca85bf
# Processing branch: origin/bugs-dot-jar_OAK-2434_8159fc21
# Processing branch: origin/bugs-dot-jar_OAK-2435_7e250001
# Processing branch: origin/bugs-dot-jar_OAK-2439_beaca1a4
# Processing branch: origin/bugs-dot-jar_OAK-2442_ea7a6199
# Processing branch: origin/bugs-dot-jar_OAK-2465_60186813
# Processing branch: origin/bugs-dot-jar_OAK-2524_977a31d8
# Processing branch: origin/bugs-dot-jar_OAK-2528_239de7b8
# Processing branch: origin/bugs-dot-jar_OAK-2559_dfa87520
# Processing branch: origin/bugs-dot-jar_OAK-2603_77d2d3b0
# Processing branch: origin/bugs-dot-jar_OAK-2642_36fe017c
# Processing branch: origin/bugs-dot-jar_OAK-2649_72d24f4b
# Processing branch: origin/bugs-dot-jar_OAK-2691_d2da7499
# Processing branch: origin/bugs-dot-jar_OAK-2695_0598498e
# Processing branch: origin/bugs-dot-jar_OAK-2740_429baf4d
# Processing branch: origin/bugs-dot-jar_OAK-276_1bf5c550
# Processing branch: origin/bugs-dot-jar_OAK-278_db19e70f
# Processing branch: origin/bugs-dot-jar_OAK-2799_3979fa8d
# Processing branch: origin/bugs-dot-jar_OAK-2864_f51ea2a2
# Processing branch: origin/bugs-dot-jar_OAK-2929_a2950285
# Processing branch: origin/bugs-dot-jar_OAK-2933_44585b0c
# Processing branch: origin/bugs-dot-jar_OAK-296_5449bf39
# Processing branch: origin/bugs-dot-jar_OAK-2999_3bf07779
# Processing branch: origin/bugs-dot-jar_OAK-3013_eabb4066
# Processing branch: origin/bugs-dot-jar_OAK-3019_5135cf4b
# Processing branch: origin/bugs-dot-jar_OAK-3020_147515ae
# Processing branch: origin/bugs-dot-jar_OAK-3021_494da6de
# Processing branch: origin/bugs-dot-jar_OAK-3028_89317b28
# Processing branch: origin/bugs-dot-jar_OAK-3053_7552a10b
# Processing branch: origin/bugs-dot-jar_OAK-3079_33c18762
# Processing branch: origin/bugs-dot-jar_OAK-3082_29e5b734
# Processing branch: origin/bugs-dot-jar_OAK-3089_ba38c380
# Processing branch: origin/bugs-dot-jar_OAK-3099_25850476
# Processing branch: origin/bugs-dot-jar_OAK-3104_38f5ef13
# Processing branch: origin/bugs-dot-jar_OAK-3105_311e8b33
# Processing branch: origin/bugs-dot-jar_OAK-3110_d10362c0
# Processing branch: origin/bugs-dot-jar_OAK-3123_f3c9c818
# Processing branch: origin/bugs-dot-jar_OAK-3137_c65b07c3
# Processing branch: origin/bugs-dot-jar_OAK-313_e115fd90
# Processing branch: origin/bugs-dot-jar_OAK-3156_786b3d76
# Processing branch: origin/bugs-dot-jar_OAK-3249_64712735
# Processing branch: origin/bugs-dot-jar_OAK-3310_4416a9f8
# Processing branch: origin/bugs-dot-jar_OAK-3318_e12e2052
# Processing branch: origin/bugs-dot-jar_OAK-3324_5f863af6
# Processing branch: origin/bugs-dot-jar_OAK-3333_194999ed
# Processing branch: origin/bugs-dot-jar_OAK-3367_06812d25
# Processing branch: origin/bugs-dot-jar_OAK-3377_00b9bc52
# Processing branch: origin/bugs-dot-jar_OAK-3396_c83755c3
# Processing branch: origin/bugs-dot-jar_OAK-3411_978c77ff
# Processing branch: origin/bugs-dot-jar_OAK-3412_2f85bd78
# Processing branch: origin/bugs-dot-jar_OAK-3424_f4349a96
# Processing branch: origin/bugs-dot-jar_OAK-3433_b76b31f7
# Processing branch: origin/bugs-dot-jar_OAK-3442_17032c50
# Processing branch: origin/bugs-dot-jar_OAK-3474_ff81ef72
# Processing branch: origin/bugs-dot-jar_OAK-3510_01f5a26f
# Processing branch: origin/bugs-dot-jar_OAK-3511_5138a1e2
# Processing branch: origin/bugs-dot-jar_OAK-3517_24f7f60a
# Processing branch: origin/bugs-dot-jar_OAK-3530_4d231938
# Processing branch: origin/bugs-dot-jar_OAK-3549_9772f5b2
# Processing branch: origin/bugs-dot-jar_OAK-3579_2565d74a
# Processing branch: origin/bugs-dot-jar_OAK-3630_fcd64766
# Processing branch: origin/bugs-dot-jar_OAK-3634_90ad50da
# Processing branch: origin/bugs-dot-jar_OAK-369_4e245a76
# Processing branch: origin/bugs-dot-jar_OAK-3733_a5ff019e
# Processing branch: origin/bugs-dot-jar_OAK-3763_ab1a0cc2
# Processing branch: origin/bugs-dot-jar_OAK-3769_306a9e00
# Processing branch: origin/bugs-dot-jar_OAK-3792_94110f21
# Processing branch: origin/bugs-dot-jar_OAK-3798_2ac1dccd
# Processing branch: origin/bugs-dot-jar_OAK-379_621a5101
# Processing branch: origin/bugs-dot-jar_OAK-3817_2a02a138
# Processing branch: origin/bugs-dot-jar_OAK-3872_c13708e3
# Processing branch: origin/bugs-dot-jar_OAK-3879_4faf31e3
# Processing branch: origin/bugs-dot-jar_OAK-3897_94c6c575
# Processing branch: origin/bugs-dot-jar_OAK-3903_690fb9f4
# Processing branch: origin/bugs-dot-jar_OAK-3920_99996c25
# Processing branch: origin/bugs-dot-jar_OAK-3930_b939aa6e
# Processing branch: origin/bugs-dot-jar_OAK-395_4ed7bc8e
# Processing branch: origin/bugs-dot-jar_OAK-395_e6c31270
# Processing branch: origin/bugs-dot-jar_OAK-4036_f4324736
# Processing branch: origin/bugs-dot-jar_OAK-4038_557eec4f
# Processing branch: origin/bugs-dot-jar_OAK-4050_52ca008c
# Processing branch: origin/bugs-dot-jar_OAK-4066_9a109aa3
# Processing branch: origin/bugs-dot-jar_OAK-4067_56accddf
# Processing branch: origin/bugs-dot-jar_OAK-4153_9120fd1b
# Processing branch: origin/bugs-dot-jar_OAK-4166_374e3f3d
# Processing branch: origin/bugs-dot-jar_OAK-4170_2a489d05
# Processing branch: origin/bugs-dot-jar_OAK-421_36e70bd7
# Processing branch: origin/bugs-dot-jar_OAK-428_916cd92f
# Processing branch: origin/bugs-dot-jar_OAK-4291_cdb34ffc
# Processing branch: origin/bugs-dot-jar_OAK-429_c02ecef8
# Processing branch: origin/bugs-dot-jar_OAK-4300_06c367af
# Processing branch: origin/bugs-dot-jar_OAK-4307_f303c916
# Processing branch: origin/bugs-dot-jar_OAK-4351_59a83d23
# Processing branch: origin/bugs-dot-jar_OAK-4353_b0014b7d
# Processing branch: origin/bugs-dot-jar_OAK-4358_74cbba24
# Processing branch: origin/bugs-dot-jar_OAK-4359_002c5845
# Processing branch: origin/bugs-dot-jar_OAK-4376_037dea72
# Processing branch: origin/bugs-dot-jar_OAK-4387_ca05fd06
# Processing branch: origin/bugs-dot-jar_OAK-4397_e33516d5
# Processing branch: origin/bugs-dot-jar_OAK-43_668f08f2
# Processing branch: origin/bugs-dot-jar_OAK-4420_d645112f
# Processing branch: origin/bugs-dot-jar_OAK-4423_08f0b280
# Processing branch: origin/bugs-dot-jar_OAK-4423_275eca83
# Processing branch: origin/bugs-dot-jar_OAK-4431_7441a3d5
# Processing branch: origin/bugs-dot-jar_OAK-4432_c9765c21
# Processing branch: origin/bugs-dot-jar_OAK-447_00df38d2
# Processing branch: origin/bugs-dot-jar_OAK-448_999097e1
# Processing branch: origin/bugs-dot-jar_OAK-478_a7f0e808
# Processing branch: origin/bugs-dot-jar_OAK-479_3270e761
# Processing branch: origin/bugs-dot-jar_OAK-47_b62f1c26
# Processing branch: origin/bugs-dot-jar_OAK-498_f2a2edec
# Processing branch: origin/bugs-dot-jar_OAK-499_61381ea2
# Processing branch: origin/bugs-dot-jar_OAK-509_b896c926
# Processing branch: origin/bugs-dot-jar_OAK-510_f63d745a
# Processing branch: origin/bugs-dot-jar_OAK-520_ec961a38
# Processing branch: origin/bugs-dot-jar_OAK-531_90c45a02
# Processing branch: origin/bugs-dot-jar_OAK-537_a8493efc
# Processing branch: origin/bugs-dot-jar_OAK-539_ffa818f3
# Processing branch: origin/bugs-dot-jar_OAK-543_3ce758b7
# Processing branch: origin/bugs-dot-jar_OAK-546_428e32c6
# Processing branch: origin/bugs-dot-jar_OAK-548_717186d6
# Processing branch: origin/bugs-dot-jar_OAK-554_3f51fb09
# Processing branch: origin/bugs-dot-jar_OAK-579_7d72e6ed
# Processing branch: origin/bugs-dot-jar_OAK-596_9b268da0
# Processing branch: origin/bugs-dot-jar_OAK-606_f0fbacab
# Processing branch: origin/bugs-dot-jar_OAK-612_df9e6913
# Processing branch: origin/bugs-dot-jar_OAK-614_6feacf6b
# Processing branch: origin/bugs-dot-jar_OAK-621_00b4b8a0
# Processing branch: origin/bugs-dot-jar_OAK-642_7a84b3a8
# Processing branch: origin/bugs-dot-jar_OAK-644_55a4f738
# Processing branch: origin/bugs-dot-jar_OAK-678_6c54045d
# Processing branch: origin/bugs-dot-jar_OAK-738_8ed779dc
# Processing branch: origin/bugs-dot-jar_OAK-740_35a7f014
# Processing branch: origin/bugs-dot-jar_OAK-748_503451c1
# Processing branch: origin/bugs-dot-jar_OAK-766_6fc5ea9d
# Processing branch: origin/bugs-dot-jar_OAK-782_45b110e1
# Processing branch: origin/bugs-dot-jar_OAK-846_7acb091a
# Processing branch: origin/bugs-dot-jar_OAK-847_65aa40dd
# Processing branch: origin/bugs-dot-jar_OAK-888_6d82cb64
# Processing branch: origin/bugs-dot-jar_OAK-926_e1ae968c
# Processing branch: origin/bugs-dot-jar_OAK-93_0be7e8f0
# Processing project: logging-log4j2
# Processing branch: origin/bugs-dot-jar_LOG4J2-1008_0c20bfd8
# Processing branch: origin/bugs-dot-jar_LOG4J2-101_c79a743b
# Processing branch: origin/bugs-dot-jar_LOG4J2-1025_a96b455c
# Processing branch: origin/bugs-dot-jar_LOG4J2-102_7f391872
# Processing branch: origin/bugs-dot-jar_LOG4J2-1046_11960820
# Processing branch: origin/bugs-dot-jar_LOG4J2-104_3b12e13d
# Processing branch: origin/bugs-dot-jar_LOG4J2-1058_c8fd3c53
# Processing branch: origin/bugs-dot-jar_LOG4J2-1061_86d8944f
# Processing branch: origin/bugs-dot-jar_LOG4J2-1062_4cf831b6
# Processing branch: origin/bugs-dot-jar_LOG4J2-1067_4786a739
# Processing branch: origin/bugs-dot-jar_LOG4J2-1068_e7bbeceb
# Processing branch: origin/bugs-dot-jar_LOG4J2-1069_e9b628ec
# Processing branch: origin/bugs-dot-jar_LOG4J2-107_88641f49
# Processing branch: origin/bugs-dot-jar_LOG4J2-1099_3f41ff48
# Processing branch: origin/bugs-dot-jar_LOG4J2-113_fc3e9d2d
# Processing branch: origin/bugs-dot-jar_LOG4J2-114_afcf92eb
# Processing branch: origin/bugs-dot-jar_LOG4J2-1153_8acedb4e
# Processing branch: origin/bugs-dot-jar_LOG4J2-1153_9f924f10
# Processing branch: origin/bugs-dot-jar_LOG4J2-1251_424068f7
# Processing branch: origin/bugs-dot-jar_LOG4J2-127_029e79da
# Processing branch: origin/bugs-dot-jar_LOG4J2-1310_c6318b63
# Processing branch: origin/bugs-dot-jar_LOG4J2-1372_1d12bf0e
# Processing branch: origin/bugs-dot-jar_LOG4J2-1372_ffedf33f
# Processing branch: origin/bugs-dot-jar_LOG4J2-139_50e19247
# Processing branch: origin/bugs-dot-jar_LOG4J2-1402_7792679c
# Processing branch: origin/bugs-dot-jar_LOG4J2-1406_a523dcd5
# Processing branch: origin/bugs-dot-jar_LOG4J2-143_1461f1f6
# Processing branch: origin/bugs-dot-jar_LOG4J2-147_17296089
# Processing branch: origin/bugs-dot-jar_LOG4J2-177_f91ce934
# Processing branch: origin/bugs-dot-jar_LOG4J2-210_aeb6fc9d
# Processing branch: origin/bugs-dot-jar_LOG4J2-219_ed951c76
# Processing branch: origin/bugs-dot-jar_LOG4J2-234_2d7d6311
# Processing branch: origin/bugs-dot-jar_LOG4J2-258_7b38965d
# Processing branch: origin/bugs-dot-jar_LOG4J2-259_09175c8b
# Processing branch: origin/bugs-dot-jar_LOG4J2-260_9d817953
# Processing branch: origin/bugs-dot-jar_LOG4J2-268_8faf7f77
# Processing branch: origin/bugs-dot-jar_LOG4J2-293_25cb587a
# Processing branch: origin/bugs-dot-jar_LOG4J2-293_ca59ece6
# Processing branch: origin/bugs-dot-jar_LOG4J2-302_300bc575
# Processing branch: origin/bugs-dot-jar_LOG4J2-310_3f1e0fdc
# Processing branch: origin/bugs-dot-jar_LOG4J2-344_8dead3bb
# Processing branch: origin/bugs-dot-jar_LOG4J2-359_1df1db27
# Processing branch: origin/bugs-dot-jar_LOG4J2-359_296ea4a5
# Processing branch: origin/bugs-dot-jar_LOG4J2-368_a8a24357
# Processing branch: origin/bugs-dot-jar_LOG4J2-378_ef8517e4
# Processing branch: origin/bugs-dot-jar_LOG4J2-385_7c2ce5cf
# Processing branch: origin/bugs-dot-jar_LOG4J2-392_731c84b5
# Processing branch: origin/bugs-dot-jar_LOG4J2-395_a19ecc9e
# Processing branch: origin/bugs-dot-jar_LOG4J2-398_2c966ad9
# Processing branch: origin/bugs-dot-jar_LOG4J2-410_8f0c4871
# Processing branch: origin/bugs-dot-jar_LOG4J2-430_238ce8aa
# Processing branch: origin/bugs-dot-jar_LOG4J2-447_0343e9c7
# Processing branch: origin/bugs-dot-jar_LOG4J2-464_484c865f
# Processing branch: origin/bugs-dot-jar_LOG4J2-466_7b9e48e8
# Processing branch: origin/bugs-dot-jar_LOG4J2-470_50340d0c
# Processing branch: origin/bugs-dot-jar_LOG4J2-478_11763dee
# Processing branch: origin/bugs-dot-jar_LOG4J2-492_24a3bed4
# Processing branch: origin/bugs-dot-jar_LOG4J2-492_61ccbb95
# Processing branch: origin/bugs-dot-jar_LOG4J2-492_a759d8ae
# Processing branch: origin/bugs-dot-jar_LOG4J2-523_837dcd89
# Processing branch: origin/bugs-dot-jar_LOG4J2-56_3eb44094
# Processing branch: origin/bugs-dot-jar_LOG4J2-581_bb02fa15
# Processing branch: origin/bugs-dot-jar_LOG4J2-619_3b4b370e
# Processing branch: origin/bugs-dot-jar_LOG4J2-639_a5a1f1a2
# Processing branch: origin/bugs-dot-jar_LOG4J2-668_60f64cc1
# Processing branch: origin/bugs-dot-jar_LOG4J2-676_3b2e880e
# Processing branch: origin/bugs-dot-jar_LOG4J2-71_2afe3dff
# Processing branch: origin/bugs-dot-jar_LOG4J2-742_4b77622b
# Processing branch: origin/bugs-dot-jar_LOG4J2-763_97203de8
# Processing branch: origin/bugs-dot-jar_LOG4J2-763_b2ec5106
# Processing branch: origin/bugs-dot-jar_LOG4J2-793_73400bfb
# Processing branch: origin/bugs-dot-jar_LOG4J2-811_7bb1ad47
# Processing branch: origin/bugs-dot-jar_LOG4J2-813_0bea17d7
# Processing branch: origin/bugs-dot-jar_LOG4J2-832_411dad65
# Processing branch: origin/bugs-dot-jar_LOG4J2-834_d3989b40
# Processing branch: origin/bugs-dot-jar_LOG4J2-892_f9b0bbee
# Processing branch: origin/bugs-dot-jar_LOG4J2-914_f8a42197
# Processing branch: origin/bugs-dot-jar_LOG4J2-94_d8af1c93
# Processing branch: origin/bugs-dot-jar_LOG4J2-964_16ad8763
# Processing branch: origin/bugs-dot-jar_LOG4J2-965_43517f15
# ...
# Processing branch: origin/bugs-dot-jar_WICKET-2368_fae1601b
# Processing branch: origin/bugs-dot-jar_WICKET-2506_0f8a2990
# Processing branch: origin/bugs-dot-jar_WICKET-2552_12e1f39b
# Processing branch: origin/bugs-dot-jar_WICKET-2569_9ced53a5
# Processing branch: origin/bugs-dot-jar_WICKET-2609_7da4ad17
# Processing branch: origin/bugs-dot-jar_WICKET-2621_c849f986
# Processing branch: origin/bugs-dot-jar_WICKET-2624_ef880545
# Processing branch: origin/bugs-dot-jar_WICKET-2839_15477252
# Processing branch: origin/bugs-dot-jar_WICKET-2882_ebe56869
# Processing branch: origin/bugs-dot-jar_WICKET-2900_0e70ce39
# Processing branch: origin/bugs-dot-jar_WICKET-294_5c592d85
# Processing branch: origin/bugs-dot-jar_WICKET-2961_3d8c9d75
# Processing branch: origin/bugs-dot-jar_WICKET-2993_0b4f78cc
# Processing branch: origin/bugs-dot-jar_WICKET-3065_b293b75c
# Processing branch: origin/bugs-dot-jar_WICKET-3076_d3dc9a50
# Processing branch: origin/bugs-dot-jar_WICKET-3098_1b7afefc
# Processing branch: origin/bugs-dot-jar_WICKET-3166_4d7f7359
# Processing branch: origin/bugs-dot-jar_WICKET-3174_0cf14725
# Processing branch: origin/bugs-dot-jar_WICKET-3196_f1c0f263
# Processing branch: origin/bugs-dot-jar_WICKET-3197_be70e608
# Processing branch: origin/bugs-dot-jar_WICKET-3222_5729ed90
# Processing branch: origin/bugs-dot-jar_WICKET-3253_71b6e905
# Processing branch: origin/bugs-dot-jar_WICKET-3272_c86b972a
# Processing branch: origin/bugs-dot-jar_WICKET-3278_60d07288
# Processing branch: origin/bugs-dot-jar_WICKET-3280_295e73bd
# Processing branch: origin/bugs-dot-jar_WICKET-3297_71499e17
# Processing branch: origin/bugs-dot-jar_WICKET-3304_7e7ab76c
# Processing branch: origin/bugs-dot-jar_WICKET-3309_debca73b
# Processing branch: origin/bugs-dot-jar_WICKET-3333_ddf7e8a2
# Processing branch: origin/bugs-dot-jar_WICKET-3413_499a9c6b
# Processing branch: origin/bugs-dot-jar_WICKET-3420_be97d017
# Processing branch: origin/bugs-dot-jar_WICKET-3428_ffc0cae9
# Processing branch: origin/bugs-dot-jar_WICKET-3454_f1e854b3
# Processing branch: origin/bugs-dot-jar_WICKET-3455_f30bd1cb
# Processing branch: origin/bugs-dot-jar_WICKET-3510_292a2582
# Processing branch: origin/bugs-dot-jar_WICKET-3511_4a875f46
# Processing branch: origin/bugs-dot-jar_WICKET-3514_2b6da516
# Processing branch: origin/bugs-dot-jar_WICKET-3520_d1b62639
# Processing branch: origin/bugs-dot-jar_WICKET-3539_a4459ef4
# Processing branch: origin/bugs-dot-jar_WICKET-3563_c62b66c1
# Processing branch: origin/bugs-dot-jar_WICKET-3597_5e2c6702
# Processing branch: origin/bugs-dot-jar_WICKET-3598_7c364566
# Processing branch: origin/bugs-dot-jar_WICKET-3603_aa1d177a
# Processing branch: origin/bugs-dot-jar_WICKET-3617_7ae109a6
# Processing branch: origin/bugs-dot-jar_WICKET-3618_fbfd17e6
# Processing branch: origin/bugs-dot-jar_WICKET-3620_1a2bc1bc
# Processing branch: origin/bugs-dot-jar_WICKET-3644_ab1856db
# Processing branch: origin/bugs-dot-jar_WICKET-3646_12124902
# Processing branch: origin/bugs-dot-jar_WICKET-3647_1b57b51c
# Processing branch: origin/bugs-dot-jar_WICKET-3702_a08562a7
# Processing branch: origin/bugs-dot-jar_WICKET-3713_e1168a57
# Processing branch: origin/bugs-dot-jar_WICKET-3715_557de7bc
# Processing branch: origin/bugs-dot-jar_WICKET-3719_5ad32df9
# Processing branch: origin/bugs-dot-jar_WICKET-3721_1858bc18
# Processing branch: origin/bugs-dot-jar_WICKET-3764_48454f4d
# Processing branch: origin/bugs-dot-jar_WICKET-3767_84c3baac
# Processing branch: origin/bugs-dot-jar_WICKET-3769_b4e9d426
# Processing branch: origin/bugs-dot-jar_WICKET-3834_30255f11
# Processing branch: origin/bugs-dot-jar_WICKET-3834_747bccb5
# Processing branch: origin/bugs-dot-jar_WICKET-3836_843b76b1
# Processing branch: origin/bugs-dot-jar_WICKET-3838_97514205
# Processing branch: origin/bugs-dot-jar_WICKET-3845_afc7034d
# Processing branch: origin/bugs-dot-jar_WICKET-3861_d1e0e411
# Processing branch: origin/bugs-dot-jar_WICKET-3872_3feb0e3a
# Processing branch: origin/bugs-dot-jar_WICKET-3884_b772ff87
# Processing branch: origin/bugs-dot-jar_WICKET-3885_beb9086d
# Processing branch: origin/bugs-dot-jar_WICKET-3906_aadaa4e9
# Processing branch: origin/bugs-dot-jar_WICKET-3931_8fbdc68f
# Processing branch: origin/bugs-dot-jar_WICKET-3965_6051019b
# Processing branch: origin/bugs-dot-jar_WICKET-3989_6a8fc1cc
# Processing branch: origin/bugs-dot-jar_WICKET-3998_b76f9c44
# Processing branch: origin/bugs-dot-jar_WICKET-4000_38e928c1
# Processing branch: origin/bugs-dot-jar_WICKET-4012_d35d2d85
# Processing branch: origin/bugs-dot-jar_WICKET-4014_e60bac5f
# Processing branch: origin/bugs-dot-jar_WICKET-4016_f1c9cef2
# Processing branch: origin/bugs-dot-jar_WICKET-4020_081cdeb2
# Processing branch: origin/bugs-dot-jar_WICKET-4030_5f69685d
# Processing branch: origin/bugs-dot-jar_WICKET-4038_f3d7565c
# Processing branch: origin/bugs-dot-jar_WICKET-4066_4d3d1f85
# Processing branch: origin/bugs-dot-jar_WICKET-4070_d450acb0
# Processing branch: origin/bugs-dot-jar_WICKET-4072_7d5b8645
# Processing branch: origin/bugs-dot-jar_WICKET-4099_1dcaec98
# Processing branch: origin/bugs-dot-jar_WICKET-4102_e743fd7e
# Processing branch: origin/bugs-dot-jar_WICKET-4105_64656c98
# Processing branch: origin/bugs-dot-jar_WICKET-4109_8f7805f8
# Processing branch: origin/bugs-dot-jar_WICKET-4116_4624ab3d
# Processing branch: origin/bugs-dot-jar_WICKET-4119_bb7a6995
# Processing branch: origin/bugs-dot-jar_WICKET-4121_8967eb2b
# Processing branch: origin/bugs-dot-jar_WICKET-4138_7c89598a
# Processing branch: origin/bugs-dot-jar_WICKET-4153_2737d7c7
# Processing branch: origin/bugs-dot-jar_WICKET-4173_84bbbf68
# Processing branch: origin/bugs-dot-jar_WICKET-4184_a0150366
# Processing branch: origin/bugs-dot-jar_WICKET-4185_5fd03973
# Processing branch: origin/bugs-dot-jar_WICKET-4251_53bcb78d
# Processing branch: origin/bugs-dot-jar_WICKET-4255_c250db9c
# Processing branch: origin/bugs-dot-jar_WICKET-4256_09166ea8
# Processing branch: origin/bugs-dot-jar_WICKET-4259_1f128536
# Processing branch: origin/bugs-dot-jar_WICKET-4260_925cae5c
# Processing branch: origin/bugs-dot-jar_WICKET-4276_32c76c4a
# Processing branch: origin/bugs-dot-jar_WICKET-428_4a6a573b
# Processing branch: origin/bugs-dot-jar_WICKET-428_d906576c
# Processing branch: origin/bugs-dot-jar_WICKET-4290_e1953357
# Processing branch: origin/bugs-dot-jar_WICKET-4292_9cb617ae
# Processing branch: origin/bugs-dot-jar_WICKET-4301_50b52742
# Processing branch: origin/bugs-dot-jar_WICKET-4309_b4274415
# Processing branch: origin/bugs-dot-jar_WICKET-4323_e24874da
# Processing branch: origin/bugs-dot-jar_WICKET-4338_9decad35
# Processing branch: origin/bugs-dot-jar_WICKET-4345_4f08e6f2
# Processing branch: origin/bugs-dot-jar_WICKET-4358_02ebc8ae
# Processing branch: origin/bugs-dot-jar_WICKET-4365_1485a856
# Processing branch: origin/bugs-dot-jar_WICKET-4370_7ca927c1
# Processing branch: origin/bugs-dot-jar_WICKET-4379_7a162f77
# Processing branch: origin/bugs-dot-jar_WICKET-4384_614e3b50
# Processing branch: origin/bugs-dot-jar_WICKET-4391_5d64196a
# Processing branch: origin/bugs-dot-jar_WICKET-4398_f88721fd
# Processing branch: origin/bugs-dot-jar_WICKET-442_246d53c5
# Processing branch: origin/bugs-dot-jar_WICKET-4441_54c86ebb
# Processing branch: origin/bugs-dot-jar_WICKET-4477_2624d2db
# Processing branch: origin/bugs-dot-jar_WICKET-4483_53442bb4
# Processing branch: origin/bugs-dot-jar_WICKET-4488_e6582c52
# Processing branch: origin/bugs-dot-jar_WICKET-4494_35843c19
# Processing branch: origin/bugs-dot-jar_WICKET-4505_a4caaa57
# Processing branch: origin/bugs-dot-jar_WICKET-4509_b672cb2d
# Processing branch: origin/bugs-dot-jar_WICKET-4511_4ee5ad1f
# Processing branch: origin/bugs-dot-jar_WICKET-4518_a88882f7
# Processing branch: origin/bugs-dot-jar_WICKET-4519_e62ded51
# Processing branch: origin/bugs-dot-jar_WICKET-4520_b91154ea
# Processing branch: origin/bugs-dot-jar_WICKET-4520_ccb8fc9e
# Processing branch: origin/bugs-dot-jar_WICKET-4548_9a6a06be
# Processing branch: origin/bugs-dot-jar_WICKET-4572_dfc56674
# Processing branch: origin/bugs-dot-jar_WICKET-4578_c66cf607
# Processing branch: origin/bugs-dot-jar_WICKET-4594_556a2236
# Processing branch: origin/bugs-dot-jar_WICKET-4594_5e1bf8d8
# Processing branch: origin/bugs-dot-jar_WICKET-4597_9dab1bb5
# Processing branch: origin/bugs-dot-jar_WICKET-4610_b19a3d69
# Processing branch: origin/bugs-dot-jar_WICKET-4616_dd1df04b
# Processing branch: origin/bugs-dot-jar_WICKET-4658_ef3adb12
# Processing branch: origin/bugs-dot-jar_WICKET-4659_ccd74641
# Processing branch: origin/bugs-dot-jar_WICKET-4664_2fcb3417
# Processing branch: origin/bugs-dot-jar_WICKET-4679_f3ec1503
# Processing branch: origin/bugs-dot-jar_WICKET-4686_89184b79
# Processing branch: origin/bugs-dot-jar_WICKET-4696_f5f802c5
# Processing branch: origin/bugs-dot-jar_WICKET-4715_4fc82e35
# Processing branch: origin/bugs-dot-jar_WICKET-4717_6a1b2f61
# Processing branch: origin/bugs-dot-jar_WICKET-4738_a7ce7f91
# Processing branch: origin/bugs-dot-jar_WICKET-4753_21a47387
# Processing branch: origin/bugs-dot-jar_WICKET-4755_87ae870f
# Processing branch: origin/bugs-dot-jar_WICKET-4757_fd910746
# Processing branch: origin/bugs-dot-jar_WICKET-4760_2f1ece4b
# Processing branch: origin/bugs-dot-jar_WICKET-4766_cda34428
# Processing branch: origin/bugs-dot-jar_WICKET-4775_1ac05533
# Processing branch: origin/bugs-dot-jar_WICKET-4777_eccb3b11
# Processing branch: origin/bugs-dot-jar_WICKET-4789_6f0863f4
# Processing branch: origin/bugs-dot-jar_WICKET-4816_66bfc885
# Processing branch: origin/bugs-dot-jar_WICKET-4824_ad849602
# Processing branch: origin/bugs-dot-jar_WICKET-4839_8b294488
# Processing branch: origin/bugs-dot-jar_WICKET-4841_ce172da8
# Processing branch: origin/bugs-dot-jar_WICKET-4877_6470c3f7
# Processing branch: origin/bugs-dot-jar_WICKET-4923_d78132be
# Processing branch: origin/bugs-dot-jar_WICKET-4927_8c827e33
# Processing branch: origin/bugs-dot-jar_WICKET-4932_f20b2d70
# Processing branch: origin/bugs-dot-jar_WICKET-4988_a4a3a9a6
# Processing branch: origin/bugs-dot-jar_WICKET-4997_ee02c883
# Processing branch: origin/bugs-dot-jar_WICKET-5019_917dd2b5
# Processing branch: origin/bugs-dot-jar_WICKET-5043_2b1ce91d
# Processing branch: origin/bugs-dot-jar_WICKET-5056_56169634
# Processing branch: origin/bugs-dot-jar_WICKET-5060_8e6a6ec5
# Processing branch: origin/bugs-dot-jar_WICKET-5071_6e794ad0
# Processing branch: origin/bugs-dot-jar_WICKET-5071_a2f848f2
# Processing branch: origin/bugs-dot-jar_WICKET-5071_d3d42d42
# Processing branch: origin/bugs-dot-jar_WICKET-5071_faaae8d3
# Processing branch: origin/bugs-dot-jar_WICKET-5072_381b90fd
# Processing branch: origin/bugs-dot-jar_WICKET-5082_217fbb3b
# Processing branch: origin/bugs-dot-jar_WICKET-5085_581c7306
# Processing branch: origin/bugs-dot-jar_WICKET-5086_ba516f02
# Processing branch: origin/bugs-dot-jar_WICKET-5094_74e77676
# Processing branch: origin/bugs-dot-jar_WICKET-5102_d110e307
# Processing branch: origin/bugs-dot-jar_WICKET-5112_ed780cc7
# Processing branch: origin/bugs-dot-jar_WICKET-5114_518c933b
# Processing branch: origin/bugs-dot-jar_WICKET-5131_4b7367ef
# Processing branch: origin/bugs-dot-jar_WICKET-5138_e8dab4a0
# Processing branch: origin/bugs-dot-jar_WICKET-5147_184e51e9
# Processing branch: origin/bugs-dot-jar_WICKET-5157_961f2477
# Processing branch: origin/bugs-dot-jar_WICKET-5165_0d4d1df7
# Processing branch: origin/bugs-dot-jar_WICKET-5176_34634266
# Processing branch: origin/bugs-dot-jar_WICKET-5203_2293764f
# Processing branch: origin/bugs-dot-jar_WICKET-5204_9e6efa61
# Processing branch: origin/bugs-dot-jar_WICKET-5209_55eb5212
# Processing branch: origin/bugs-dot-jar_WICKET-5226_8e518d88
# Processing branch: origin/bugs-dot-jar_WICKET-5230_9c8f658a
# Processing branch: origin/bugs-dot-jar_WICKET-5237_b61fe92c
# Processing branch: origin/bugs-dot-jar_WICKET-5247_44a4132f
# Processing branch: origin/bugs-dot-jar_WICKET-5250_6122df49
# Processing branch: origin/bugs-dot-jar_WICKET-5251_3d2393c7
# Processing branch: origin/bugs-dot-jar_WICKET-5251_6ce34ccf
# Processing branch: origin/bugs-dot-jar_WICKET-5259_a9e56e1e
# Processing branch: origin/bugs-dot-jar_WICKET-5265_0eb596df
# Processing branch: origin/bugs-dot-jar_WICKET-5319_c863b032
# Processing branch: origin/bugs-dot-jar_WICKET-5326_ded3c583
# Processing branch: origin/bugs-dot-jar_WICKET-5345_3fc7234e
# Processing branch: origin/bugs-dot-jar_WICKET-5359_61122bab
# Processing branch: origin/bugs-dot-jar_WICKET-5398_19e7c1cd
# Processing branch: origin/bugs-dot-jar_WICKET-5400_6cefb9f8
# Processing branch: origin/bugs-dot-jar_WICKET-5416_87fa630f
# Processing branch: origin/bugs-dot-jar_WICKET-5418_e350f19e
# Processing branch: origin/bugs-dot-jar_WICKET-5426_fb45a781
# Processing branch: origin/bugs-dot-jar_WICKET-5441_8ccb1f6d
# Processing branch: origin/bugs-dot-jar_WICKET-5442_a382917f
# Processing branch: origin/bugs-dot-jar_WICKET-5447_2abc18f1
# Processing branch: origin/bugs-dot-jar_WICKET-5460_a3a5a40f
# Processing branch: origin/bugs-dot-jar_WICKET-5466_c1c1f794
# Processing branch: origin/bugs-dot-jar_WICKET-5476_813d8bee
# Processing branch: origin/bugs-dot-jar_WICKET-5484_ecdfc124
# Processing branch: origin/bugs-dot-jar_WICKET-5486_a79ed51e
# Processing branch: origin/bugs-dot-jar_WICKET-5497_724066f4
# Processing branch: origin/bugs-dot-jar_WICKET-5500_825da305
# Processing branch: origin/bugs-dot-jar_WICKET-5505_6cceff44
# Processing branch: origin/bugs-dot-jar_WICKET-5518_c2e12216
# Processing branch: origin/bugs-dot-jar_WICKET-5522_5b730c0b
# Processing branch: origin/bugs-dot-jar_WICKET-5546_f1af9e03
# Processing branch: origin/bugs-dot-jar_WICKET-5560_aa82ccfc
# Processing branch: origin/bugs-dot-jar_WICKET-5565_204849bc
# Processing branch: origin/bugs-dot-jar_WICKET-5565_44f4782a
# Processing branch: origin/bugs-dot-jar_WICKET-5569_5efb8091
# Processing branch: origin/bugs-dot-jar_WICKET-5570_57d8f051
# Processing branch: origin/bugs-dot-jar_WICKET-5572_cd414fa5
# Processing branch: origin/bugs-dot-jar_WICKET-5578_5cdc1c8d
# Processing branch: origin/bugs-dot-jar_WICKET-5582_1fb66533
# Processing branch: origin/bugs-dot-jar_WICKET-5603_240ab3c3
# Processing branch: origin/bugs-dot-jar_WICKET-5655_d558004b
# Processing branch: origin/bugs-dot-jar_WICKET-5656_f539c18c
# Processing branch: origin/bugs-dot-jar_WICKET-5662_9aec4f33
# Processing branch: origin/bugs-dot-jar_WICKET-5686_8e794fc4
# Processing branch: origin/bugs-dot-jar_WICKET-5689_2ac29d30
# Processing branch: origin/bugs-dot-jar_WICKET-5698_f45ce896
# Processing branch: origin/bugs-dot-jar_WICKET-5701_087c0a26
# Processing branch: origin/bugs-dot-jar_WICKET-5706_0f8a6d75
# Processing branch: origin/bugs-dot-jar_WICKET-5711_5837817c
# Processing branch: origin/bugs-dot-jar_WICKET-5712_145da021
# Processing branch: origin/bugs-dot-jar_WICKET-5720_2fc6a395
# Processing branch: origin/bugs-dot-jar_WICKET-5724_b92591f6
# Processing branch: origin/bugs-dot-jar_WICKET-5728_3cc3fe95
# Processing branch: origin/bugs-dot-jar_WICKET-5734_71674df5
# Processing branch: origin/bugs-dot-jar_WICKET-5751_bcea89fc
# Processing branch: origin/bugs-dot-jar_WICKET-5759_0374c040
# Processing branch: origin/bugs-dot-jar_WICKET-5770_cf6172bd
# Processing branch: origin/bugs-dot-jar_WICKET-5783_7b8b6767
# Processing branch: origin/bugs-dot-jar_WICKET-5784_b6259e5f
# Processing branch: origin/bugs-dot-jar_WICKET-5809_b1f4e6a3
# Processing branch: origin/bugs-dot-jar_WICKET-5838_e93fdd5a
# Processing branch: origin/bugs-dot-jar_WICKET-5853_b80f6640
# Processing branch: origin/bugs-dot-jar_WICKET-5881_8c83c5c5
# Processing branch: origin/bugs-dot-jar_WICKET-5883_cd3b9234
# Processing branch: origin/bugs-dot-jar_WICKET-5891_2d9ebf9a
# Processing branch: origin/bugs-dot-jar_WICKET-5898_b00920f3
# Processing branch: origin/bugs-dot-jar_WICKET-5898_ffdd0864
# Processing branch: origin/bugs-dot-jar_WICKET-5916_def03add
# Processing branch: origin/bugs-dot-jar_WICKET-5960_03663750
# Processing branch: origin/bugs-dot-jar_WICKET-5964_86066852
# Processing branch: origin/bugs-dot-jar_WICKET-5965_31c88569
# Processing branch: origin/bugs-dot-jar_WICKET-5966_d547fcd4
# Processing branch: origin/bugs-dot-jar_WICKET-5968_8b7946d8
# Processing branch: origin/bugs-dot-jar_WICKET-5980_294b0b2f
# Processing branch: origin/bugs-dot-jar_WICKET-5981_eb125865
# Processing branch: origin/bugs-dot-jar_WICKET-5989_a255bbca
# Data extraction complete. Saved to bugs_data1.csv.

# %% [markdown]
# ### Sección: Normalización y Expansión del DataFrame
# Descripción General
# Este bloque de código se encarga de:
#
# Cargar los datos desde un archivo CSV.
# Expandir los datos anidados en la columna bug_report para extraer los detalles del reporte de bugs.
# Combinar los datos originales con los nuevos campos extraídos.
# Guardar el DataFrame expandido en un nuevo archivo CSV para su posterior análisis.

# %%
# Re-import the CSV to ensure the DataFrame is loaded correctly
file_path = "bugs_data1.csv"
df = pd.read_csv(file_path)

# Normalize the 'bug_report' column to extract nested details into separate columns
df_bug_details = pd.json_normalize(df['bug_report'].apply(eval))  # Convert string representation of dict to dict

# Combine the normalized data with the original DataFrame, dropping the original 'bug_report' column
df_combined = pd.concat([df.drop('bug_report', axis=1), df_bug_details], axis=1)

# Save the expanded DataFrame to a new CSV
expanded_file_path = "bugs_data_expanded.csv"
df_combined.to_csv(expanded_file_path, index=False)

expanded_file_path
# Out:
# 'bugs_data_expanded.csv'

# %%
file_path = "bugs_data_expanded.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#        project                               branch          BugID  \
# 0     accumulo  bugs-dot-jar_ACCUMULO-1044_9396979b  ACCUMULO-1044
# 1     accumulo  bugs-dot-jar_ACCUMULO-1044_ea2f9856  ACCUMULO-1044
# 2     accumulo  bugs-dot-jar_ACCUMULO-1051_25cf3ccd  ACCUMULO-1051
# 3     accumulo  bugs-dot-jar_ACCUMULO-1120_474b2577  ACCUMULO-1120
# 4     accumulo  bugs-dot-jar_ACCUMULO-1183_742960f1  ACCUMULO-1183
# ...        ...                                  ...            ...
# 1153    wicket    bugs-dot-jar_WICKET-5966_d547fcd4    WICKET-5966
# 1154    wicket    bugs-dot-jar_WICKET-5968_8b7946d8    WICKET-5968
# 1155    wicket    bugs-dot-jar_WICKET-5980_294b0b2f    WICKET-5980
# 1156    wicket    bugs-dot-jar_WICKET-5981_eb125865    WICKET-5981
# 1157    wicket    bugs-dot-jar_WICKET-5989_a255bbca    WICKET-5989
#
#                                                 Summary  \
# 0     bulk imported files showing up in metadata aft...
# 1     bulk imported files showing up in metadata aft...
# 2         Authorizations has inconsistent serialization
# 3     stop-all doesn't work: Error BAD_CREDENTIALS f...
# 4     ProxyServer does not set column information on...
# ...                                                 ...
# 1153  ResourceUtils.getLocaleFromFilename can't hand...
# 1154  CachingResourceLocator lookup key doesn't take...
# 1155  When using Servlet 3.0 filter Wicket calculate...
# 1156  Significant Performance Degradation From Wicke...
# 1157  BaseWicketTester#startComponentInPage fails fo...
#
#                                             Description
# 0     Bulk import fails.  The file is moved to the f...
# 1     Bulk import fails.  The file is moved to the f...
# 2     The same set of authorizations may not seriali...
# 3     {noformat}\n$ bin/accumulo admin stopAll\n2013...
# 4     The createScanner method uses the options from...
# ...                                                 ...
# 1153  I think the ResourceUtils.getLocaleFromFilenam...
# 1154  CachingResourceLocator uses a CacheKey to stor...
# 1155  When using a servlet 3.0 filter with annotatio...
# 1156  I am experiencing a significant performance de...
# 1157  I am using the {{[BaseWicketTester.html#startC...
#
# [1158 rows x 5 columns]
